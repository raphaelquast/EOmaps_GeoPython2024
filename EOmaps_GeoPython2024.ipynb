# %% [markdown]
# <h1>EOmaps Workshop<font size=4 style="float:right">GeoPython 2024</font></h1><p>
# <font size=3>Interactive geo-data analysis with EOmaps and the scientific python infrastructure.</font>
#
#
# ## What's this workshop about?
# We'll have a look how [EOmaps]() can help you to **speed up** and **simplify** your geographic data analysis workflows
#
# 1. [Basics](#Basics)
# 2. [Companion Widget](#Companion-Widget)
# 3. [Data Visualization](#Data-Visualization)

# %% [markdown]
# # Basics
#
# <a href="https://raw.githubusercontent.com/raphaelquast/EOmaps/master/docs/_static/intro.png"><img src="https://raw.githubusercontent.com/raphaelquast/EOmaps/master/docs/_static/intro.png" width=30%></a>

# %% [markdown]
# ### Lets create a first map

# %%
# %matplotlib qt
from eomaps import Maps
Maps.config(always_on_top=True, log_level="info")      # keep figures "always on top"

# %%
# Initialize a new map
m = Maps(figsize=(6, 3), facecolor="none")
m.set_frame(rounded=0.15, ec="0.5")

# %%
m.add_feature.preset.coastline()
m.add_feature.physical.ocean(
    scale=50,
    fc="lightblue",
    ec="darkblue",
    hatch="xxx", 
    alpha=0.25,
)

# %%
m.add_compass(pos=(0.1, 0.25))
m.add_logo()

# %%
m.snapshot()

# %% [markdown]
# # Companion Widget
#
# > Press **W** while mouse is on top of an *active figure* with an EOmaps map.

# %% [markdown]
# # Data Visualization
